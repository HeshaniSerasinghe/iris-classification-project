# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
iris_data=load_iris()

x = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)

y = pd.Series(iris_data.target, name='species')

# %%
print("First 5 rows of data:")
print(x.head())

print("\nStatistical Summary:")
print(x.describe())

df_for_plot = pd.concat([x, y], axis=1)
sns.pairplot(df_for_plot, hue='species', palette='viridis')
plt.suptitle("Pair Plot of Iris Dataset Features", y=1.02)
plt.show()
# Out:
# First 5 rows of data:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Statistical Summary:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# %%
model = DecisionTreeClassifier(random_state=42)

model.fit(x_train, y_train)
print("Model training complete!")
# Out:
# Model training complete!

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 93.33%

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# Out:
# /content

# %%
# !rm -rf iris-classification-project

# %%
# !git clone https://github.com/HeshaniSerasinghe/iris-classification-project
# Out:
# Cloning into 'iris-classification-project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# NOTE: "Colab Notebooks" might have a space. Using quotes is important!
source_path = "/content/drive/MyDrive/Colab Notebooks/iris_classification.ipynb"

# The destination path inside the cloned repo
destination_path = "/content/iris-classification-project/"

# The copy command
# !cp "{source_path}" "{destination_path}"
# Out:
# /content/iris-classification-project

# %%
# !ls
# Out:
# README.md

# %%
# !git config --global user.email "serasingheheshani@gmail.com"
# !git config --global user.name "HeshaniSerasinghe"
